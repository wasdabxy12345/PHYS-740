# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pylab as p
import matplotlib.animation as animation
from scipy.integrate import solve_ivp
import math

def shm(t,u):
    omega0 = 3*math.pi
    omegaf = 2*math.pi
    tau = 2/omega0
    gamma = 1.077
    theta,omega = u
    return [omega,-(omega/tau) - (omega0**2)*math.sin(theta) + gamma*(omega0**2)*math.cos(omegaf*t)]

t0, tf = 0.0, 29.0
nt = 29
t = np.linspace(t0, tf, nt+1)
u1 = [0.0,0.0]
u2 = [-(math.pi)/2,0.0]
sol1 = solve_ivp(shm,[t0,tf],u1,t_eval=t)
sol2 = solve_ivp(shm,[t0,tf],u2,t_eval=t)

theta1 = sol1.y[0]
omega1 = sol1.y[1]
theta2 = sol2.y[0]
omega2 = sol2.y[1]



f1 = p.figure()
plt.subplot(1, 2, 1)
p.plot(t, theta1, label='θ(0) = 0')
p.plot(t, theta2, label='θ(0) = −π/2')
p.grid()
p.legend(loc='best')
p.xlabel('time (sec)')
p.ylabel('angle (rad)')
#p.title('Evolution of fox and rabbit populations')
#f1.savefig('2_3(a)1.png')

#f2 = p.figure()
plt.subplot(1, 2, 2)
#p.plot(t, theta, label='evolution of angle over time')
p.plot(omega1, theta1, label='θ(0) = 0')
p.plot(omega2, theta2, label='θ(0) = −π/2')
p.grid()
p.legend(loc='best')
p.xlabel('angular velocity (rad/sec)')
p.ylabel('angle (rad)')
#p.title('Evolution of fox and rabbit populations')
f1.savefig('2_3(a).png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pylab as p
import matplotlib.animation as animation
from scipy.integrate import solve_ivp
import math

def shm(t,u):
    omega0 = 3*math.pi
    omegaf = 2*math.pi
    tau = 2/omega0
    gamma = 1.530
    theta,omega = u
    return [omega,-(omega/tau) - (omega0**2)*math.sin(theta) + gamma*(omega0**2)*math.cos(omegaf*t)]

t0, tf = 0.0, 29.0
nt = 2900
t = np.linspace(t0, tf, nt+1)
u1 = [-(math.pi)/2,0.0]
u2 = [-((math.pi)/2)+0.0001,0.0]
sol1 = solve_ivp(shm,[t0,tf],u1,t_eval=t)
sol2 = solve_ivp(shm,[t0,tf],u2,t_eval=t)

theta1 = sol1.y[0]
omega1 = sol1.y[1]
theta2 = sol2.y[0]
omega2 = sol2.y[1]

f1 = p.figure()
plt.subplot(2, 2, 1)
p.plot(t, theta1, label='θ(0) = −π/2')
p.plot(t, theta2, label='θ(0) = −π/2+0.0001')
p.grid()
p.legend(loc='best')
p.xlabel('time (sec)')
p.ylabel('angle (rad)')
#p.title('Evolution of fox and rabbit populations')
#f1.savefig('2_3(a)1.png')

#f2 = p.figure()
plt.subplot(2, 2, 2)
#p.plot(t, theta, label='evolution of angle over time')
p.plot(omega1, theta1, label='θ(0) = −π/2')
p.plot(omega2, theta2, label='θ(0) = −π/2+0.0001')
p.grid()
p.legend(loc='best')
p.xlabel('angular velocity (rad/sec)')
p.ylabel('angle (rad)')
#p.title('Evolution of fox and rabbit populations')
#f1.savefig('2_3(a)1.png')

newtheta = np.log(abs(np.subtract(theta1,theta2)))
print(newtheta)

plt.subplot(2, 2, 3)
p.plot(t, newtheta,'-g', label='log(|∆θ(t)|)')
p.grid()
p.legend(loc='best')
p.xlabel('angular velocity (rad/sec)')
p.ylabel('angle (rad)')

t0, tf = 0.0, 5.0
nt = 2900
t1 = np.linspace(t0, tf, nt+1)
u1 = [-(math.pi)/2,0.0]
u2 = [-((math.pi)/2)+0.0001,0.0]
sol1 = solve_ivp(shm,[t0,tf],u1,t_eval=t1)
sol2 = solve_ivp(shm,[t0,tf],u2,t_eval=t1)

theta1 = sol1.y[0]
omega1 = sol1.y[1]
theta2 = sol2.y[0]
omega2 = sol2.y[1]

newtheta1 = np.log(abs(np.subtract(theta1,theta2)))

plt.subplot(2, 2, 4)
p.plot(t1, newtheta1,'-c', label='log(|∆θ(t)|)')
p.grid()
p.legend(loc='best')
p.xlabel('angular velocity (rad/sec)')
p.ylabel('angle (rad)')
f1.savefig('2_3(b).png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [-9.21034037 -9.21034547 -9.21045672 ...  0.60378728  0.59312758
#   0.57932705]
