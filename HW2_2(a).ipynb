# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
#matplotlib.use('tkagg')
from numpy import *
import pylab as p
from scipy import integrate

# angle, angular velocity
theta = np.linspace(-np.pi, np.pi, 100)

#thetadot = omega
#omegadot = -sin(theta)

theta, omega = meshgrid(arange(-1, 1, 0.1), arange(-1, 1, 0.1))
thetadot = omega
omegadot = -1*sin(theta)

f1 = plt.figure()
plt.quiver(thetadot, omegadot)
p.grid()
#p.legend(loc='best')
p.xlabel('angle (rad)')
p.ylabel('angular velocity (rad/sec)')
plt.grid(); plt.show()

f1.savefig('2_2(a).png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
#matplotlib.use('tkagg')
from numpy import *
import pylab as p
from scipy import integrate

# angle, angular velocity
theta = np.linspace(-np.pi, np.pi, 100)

#thetadot = omega
#omegadot = -sin(theta)

theta, omega = meshgrid(arange(0, 1, 0.1), arange(0, 10, 0.1))
#print(theta)
#print(omega)
thetadot = omega
omegadot = -1*sin(theta)
plt.quiver(thetadot, omegadot)
p.xlabel('dθ/dt')
p.ylabel('dω/dt')

plt.grid(); plt.show()

f1 = p.figure()
p.plot(theta, omega, label='Population of foxes')
#p.plot(t, rabbits, label='Population of rabbits')
p.grid()
#p.legend(loc='best')
p.xlabel('time (weeks)')
p.ylabel('population (thousands)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'population (thousands)')
